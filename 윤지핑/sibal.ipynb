# %%
filtered_spots = [spot for spot in data[:3] if spot['관광지명'] in str('조천함덕해안도로')]

# %%
filtered_spots
# Out:
# [{'관광지명': '조천함덕해안도로',
#   '주소': '제주특별자치도 제주시 조천읍 조함해안로 525 ',
#   '대분류': '자연',
#   '중분류': '자연관광지',
#   '소분류': '자연생태관광지',
#   '위도': 33.5313895,
#   '경도': 126.6429191,
#   '거리': 2.320016742538772}]

# %%
data[8]
# Out:
# {'관광지명': '한림공원',
#  '주소': '제주특별자치도 제주시 한림읍 한림로 300 ',
#  '대분류': '인문(문화/예술/역사)',
#  '중 분류': '휴양관광지',
#  '소분류': '공원',
#  '위도': 33.3883099,
#  '경도': 126.2394248,
#  '거리': 2.184234433226298}

# %%
len(data)
# Out:
# 9

# %%
data = [[{'관광지명': '방선문', '주소': '제주특별자치도 제주시 오라이동 39-1', '대분류': '자연', '중분류': '자연관광지', '소분류': '계곡', '위도': 33.4712097, '경도': 126.5020906, '거리': 1.8453293339652275}, {'관광지명': '수목원테마파크', '주소': '제주특 별자치도 제주시 은수길 69 ', '대분류': '인문(문화/예술/역사)', '중분류': '휴양관광 지', '소분류': '테마공원', '위도': 33.4705937, '경도': 126.4883601, '거리': 2.269125276498181}, {'관광지명': '용두암', '주소': '제주특별자치도 제주시 용두암길 (제주올레길17코스)', '대분류': '자연', '중분류': '자연관광지', '소분류': '해안절경', '위도': 33.5150353, '경도': 126.5119671, '거리': 3.1694626991218766}], [{'관광지명': '갈중이', '주소': '제주특별자치도 서귀포시 사계남로216번길 24-61 갈중이 ', '대분류': '인문(문화/예술/역사)', '중분류': '체험관광지', '소분류': '전통체험', '위도': 33.2350546, '경도': 126.3136741, '거리': 1.554219102739048}, {'관광지명': '용머리해안', '주소': '제주특별자치도 서귀포시 안덕면 사계리 118-3 ', '대분류': '자연', '중분류': '자연관광지', '소분류': '해안절경', '위도': 33.2383758, '경도': 126.3026575, '거리': 2.339543272437284}, {'관광지명': '사계해변', '주소': '제주특별자치도 서귀포시 안 덕면 사계리 2147-35', '대분류': '자연', '중분류': '자연관광지', '소분류': '해수욕장', '위도': 33.2281549, '경도': 126.3083471, '거리': 2.430861012758528}], [{'관광지 명': '조천함덕해안도로', '주소': '제주특별자치도 제주시 조천읍 조함해안로 525 ', ' 대분류': '자연', '중분류': '자연관광지', '소분류': '자연생태관광지', '위도': 33.5313895, '경도': 126.6429191, '거리': 2.0566132750255157}, {'관광지명': '다려도', '주 소': '제주특별자치도 제주시 조천읍 북촌리 산 89', '대분류': '자연', '중분류': '자연관광지', '소분류': '섬', '위도': 33.5374849, '경도': 126.6939218, '거리': 3.318534781902857}, {'관광지명': '닭머르해안길', '주소': '제주특별자치도 제주시 조천읍 신촌 북3길 62-1 ', '대분류': '자연', '중분류': '자연관광지', '소분류': '자연생태관광지', '위도': 33.5378704, '경도': 126.6132214, '거리': 4.313541437102445}]]
[[{'관광지명': '소남머리', '주소': '제주특별자치도 서귀포시 칠십리로 145 (서귀동) ', '대분류': '자연', '중분류': '자연관광지', '소분류': '해안절경', '위도': 33.2443044, '경도': 126.5690477, '거리': 0.20265996826312632}, {'관광지명': '서귀포항', '주 소': '제주특별자치도 서귀포시 칠십리로72번길 14 (서귀동)', '대분류': '자연', '중분 류': '자연관광지', '소분류': '항구/포구', '위도': 33.2382947, '경도': 126.5668633, '거리': 0.8879841118707568}, {'관광지명': '삼매봉', '주소': '제주특별자치도 서귀포 시 서홍동 820-2', '대분류': '인문(문화/예술/역사)', '중분류': '휴양관광지', '소분류': '공원', '위도': 33.2437181, '경도': 126.5462844, '거리': 2.260126181363018}], [{'관광지명': '갈중이', '주소': '제주특별자치도 서귀포시 사계남로216번길 24-61 갈중이 ', '대분류': '인문(문화/예술/역사)', '중분류': '체험관광지', '소분류': '전통체험', '위도': 33.2350546, '경도': 126.3136741, '거리': 1.554219102739048}, {'관광지명': '용머리해안', '주소': '제주특별자치도 서귀포시 안덕면 사계리 118-3 ', '대분류': '자연', '중분류': '자연관광지', '소분류': '해안절경', '위도': 33.2383758, '경도': 126.3026575, '거리': 2.339543272437284}, {'관광지명': '사계해변', '주소': '제주특별자치도 서귀포시 안덕면 사계리 2147-35', '대분류': '자연', '중분류': '자연관광지', '소분류': '해수욕장', '위도': 33.2281549, '경도': 126.3083471, '거리': 2.430861012758528}], [{'관광지명': '방선문', '주소': '제주특별자치도 제주시 오라이동 39-1', '대분류': '자연', '중분류': '자연관광지', '소분류': '계곡', '위도': 33.4712097, '경도': 126.5020906, '거리': 1.8453293339652275}, {'관광지명': '수목원테마파크', '주소': '제주특별자치도 제주시 은수길 69 ', '대분류': '인문(문화/예술/역사)', '중분류': '휴양관 광지', '소분류': '테마공원', '위도': 33.4705937, '경도': 126.4883601, '거리': 2.269125276498181}, {'관광지명': '용두암', '주소': '제주특별자치도 제주시 용두암길 (제주올레길17코스)', '대분류': '자연', '중분류': '자연관광지', '소분류': '해안절경', '위도': 33.5150353, '경도': 126.5119671, '거리': 3.1694626991218766}]]
# Out:
# [[{'관광지명': '소남머리',
#    '주소': '제주특별자치도 서귀포시 칠십리로 145 (서귀동) ',
#    '대분류': '자연',
#    '중분류': '자연관광지',
#    '소분류': '해안절경',
#    '위도': 33.2443044,
#    '경도': 126.5690477,
#    '거리': 0.20265996826312632},
#   {'관광지명': '서귀포항',
#    '주 소': '제주특별자치도 서귀포시 칠십리로72번길 14 (서귀동)',
#    '대분류': '자연',
#    '중분 류': '자연관광지',
#    '소분류': '항구/포구',
#    '위도': 33.2382947,
#    '경도': 126.5668633,
#    '거리': 0.8879841118707568},
#   {'관광지명': '삼매봉',
#    '주소': '제주특별자치도 서귀포 시 서홍동 820-2',
#    '대분류': '인문(문화/예술/역사)',
#    '중분류': '휴양관광지',
#    '소분류': '공원',
#    '위도': 33.2437181,
#    '경도': 126.5462844,
#    '거리': 2.260126181363018}],
#  [{'관광지명': '갈중이',
#    '주소': '제주특별자치도 서귀포시 사계남로216번길 24-61 갈중이 ',
#    '대분류': '인문(문화/예술/역사)',
#    '중분류': '체험관광지',
#    '소분류': '전통체험',
#    '위도': 33.2350546,
#    '경도': 126.3136741,
#    '거리': 1.554219102739048},
#   {'관광지명': '용머리해안',
#    '주소': '제주특별자치도 서귀포시 안덕면 사계리 118-3 ',
#    '대분류': '자연',
#    '중분류': '자연관광지',
#    '소분류': '해안절경',
#    '위도': 33.2383758,
#    '경도': 126.3026575,
# ...

# %%
data[0]
# Out:
# [{'관광지명': '방선문',
#   '주소': '제주특별자치도 제주시 오라이동 39-1',
#   '대분류': '자연',
#   '중분류': '자연관광지',
#   '소분류': '계곡',
#   '위도': 33.4712097,
#   '경도': 126.5020906,
#   '거리': 1.8453293339652275},
#  {'관광지명': '수목원테마파크',
#   '주소': '제주특 별자치도 제주시 은수길 69 ',
#   '대분류': '인문(문화/예술/역사)',
#   '중분류': '휴양관광 지',
#   '소분류': '테마공원',
#   '위도': 33.4705937,
#   '경도': 126.4883601,
#   '거리': 2.269125276498181},
#  {'관광지명': '용두암',
#   '주소': '제주특별자치도 제주시 용두암길 (제주올레길17코스)',
#   '대분류': '자연',
#   '중분류': '자연관광지',
#   '소분류': '해안절경',
#   '위도': 33.5150353,
#   '경도': 126.5119671,
#   '거리': 3.1694626991218766}]

# %%
data[1]
# Out:
# [{'관광지명': '갈중이',
#   '주소': '제주특별자치도 서귀포시 사계남로216번길 24-61 갈중이 ',
#   '대분류': '인문(문화/예술/역사)',
#   '중분류': '체험관광지',
#   '소분류': '전통체험',
#   '위도': 33.2350546,
#   '경도': 126.3136741,
#   '거리': 1.554219102739048},
#  {'관광지명': '용머리해안',
#   '주소': '제주특별자치도 서귀포시 안덕면 사계리 118-3 ',
#   '대분류': '자연',
#   '중분류': '자연관광지',
#   '소분류': '해안절경',
#   '위도': 33.2383758,
#   '경도': 126.3026575,
#   '거리': 2.339543272437284},
#  {'관광지명': '사계해변',
#   '주소': '제주특별자치도 서귀포시 안 덕면 사계리 2147-35',
#   '대분류': '자연',
#   '중분류': '자연관광지',
#   '소분류': '해수욕장',
#   '위도': 33.2281549,
#   '경도': 126.3083471,
#   '거리': 2.430861012758528}]

# %%
data[2]
# Out:
# [{'관광지 명': '조천함덕해안도로',
#   '주소': '제주특별자치도 제주시 조천읍 조함해안로 525 ',
#   ' 대분류': '자연',
#   '중분류': '자연관광지',
#   '소분류': '자연생태관광지',
#   '위도': 33.5313895,
#   '경도': 126.6429191,
#   '거리': 2.0566132750255157},
#  {'관광지명': '다려도',
#   '주 소': '제주특별자치도 제주시 조천읍 북촌리 산 89',
#   '대분류': '자연',
#   '중분류': '자연관광지',
#   '소분류': '섬',
#   '위도': 33.5374849,
#   '경도': 126.6939218,
#   '거리': 3.318534781902857},
#  {'관광지명': '닭머르해안길',
#   '주소': '제주특별자치도 제주시 조천읍 신촌 북3길 62-1 ',
#   '대분류': '자연',
#   '중분류': '자연관광지',
#   '소분류': '자연생태관광지',
#   '위도': 33.5378704,
#   '경도': 126.6132214,
#   '거리': 4.313541437102445}]

# %%
lst = []
for i in range(3):
    k = data[i]
    for j in range(3):
       lst.append(k[j])

# %%
lst
# Out:
# [{'관광지명': '방선문',
#   '주소': '제주특별자치도 제주시 오라이동 39-1',
#   '대분류': '자연',
#   '중분류': '자연관광지',
#   '소분류': '계곡',
#   '위도': 33.4712097,
#   '경도': 126.5020906,
#   '거리': 1.8453293339652275},
#  {'관광지명': '수목원테마파크',
#   '주소': '제주특 별자치도 제주시 은수길 69 ',
#   '대분류': '인문(문화/예술/역사)',
#   '중분류': '휴양관광 지',
#   '소분류': '테마공원',
#   '위도': 33.4705937,
#   '경도': 126.4883601,
#   '거리': 2.269125276498181},
#  {'관광지명': '용두암',
#   '주소': '제주특별자치도 제주시 용두암길 (제주올레길17코스)',
#   '대분류': '자연',
#   '중분류': '자연관광지',
#   '소분류': '해안절경',
#   '위도': 33.5150353,
#   '경도': 126.5119671,
#   '거리': 3.1694626991218766},
#  {'관광지명': '갈중이',
#   '주소': '제주특별자치도 서귀포시 사계남로216번길 24-61 갈중이 ',
#   '대분류': '인문(문화/예술/역사)',
#   '중분류': '체험관광지',
#   '소분류': '전통체험',
#   '위도': 33.2350546,
#   '경도': 126.3136741,
#   '거리': 1.554219102739048},
#  {'관광지명': '용머리해안',
#   '주소': '제주특별자치도 서귀포시 안덕면 사계리 118-3 ',
#   '대분류': '자연',
#   '중분류': '자연관광지',
#   '소분류': '해안절경',
#   '위도': 33.2383758,
#   '경도': 126.3026575,
#   '거리': 2.339543272437284},
#  {'관광지명': '사계해변',
# ...
