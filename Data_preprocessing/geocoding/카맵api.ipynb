# %%
import pandas as pd
import requests
import math
from tqdm import tqdm
from haversine import haversine

# %%
org_ = pd.read_csv('생성형AI분야_로우데이터/JEJU_MCT_DATA_v2.csv', encoding = "cp949")
ad = pd.read_csv('생성형AI분야_로우데이터/JEJU_MCT_DATA_v2.csv', encoding = "cp949")["ADDR"]

# %%
org = org_.drop_duplicates(['ADDR']) #주소 중복제거 후 나중에 같은거 처리, 8800개 정도, 관광지 39000개였나 그것도 해야함

# %%
kakao_key = open("kakao.txt", "r").read()

# %%
kakao_key = open("kakao.txt", "r").read()
def get_distance_between_to_address(addr1, i):
    response = requests.get(
        "https://dapi.kakao.com/v2/local/search/address.json",
        params={"query": addr1},
        headers={"Authorization": "KakaoAK " + kakao_key},
    ).json()
    x, y = response["documents"][0]["x"], response["documents"][0]["y"]  # x, y= 위도, 경도

    org.iloc[i,28] = x
    org.iloc[i,29] = y

# %%
org[['MCT_NM','ADDR','x1','y1']]
# Out:
#              MCT_NM                        ADDR         x1            y1
# 0              통큰돼지   제주 제주시 용담이동 2682-9번지 통큰돼지  154393.66   1549.689992
# 1                해변      제주 제주시 애월읍 애월리 410-6번지  137116.02  -2875.340008
# 2               한그릇    제주 서귀포시 색달동 2315-1번지 한그릇  145537.01 -26064.640008
# 3            협재해녀의집     제주 제주시 한림읍 협재리 1459-2번지  129661.23 -10255.320008
# 4              까망꼬숑     제주 제주시 노형동 3784-12번지 1층  151715.41  -1099.180008
# ...             ...                         ...        ...           ...
# 67859           미나리       제주 제주시 연동 291-24번지 연동
# 67860      종달리엔심야식당  제주 제주시 구좌읍 종달리 1935-1번지 1층
# 67861          경일낙지         제주 제주시 노형동 1291-3번지
# 67862      흑돼지가있는풍경            제주 제주시 노형동 668번지
# 67863  에이바우트커피삼무공원점       제주 제주시 연동 260-21번지 1층
#
# [67864 rows x 4 columns]

# %%
# LLM이 맛집 하나 찾으면 해당 맛집의 위도, 경도를 기준으로 아래 함수를 수행해서 가까운 관광지 찾을 수 있을까? 몇 키로 이내로 지정 해줘야할듯

# 위경도 입력
Seoul = (33.5066481356656, 126.509165318787)  #Latitude, Longitude
Toronto = (33.465878379509, 126.323536037201)

# 거리 계산
haversine(Seoul, Toronto, unit = 'km')

# %%
# 두 번째

# %%
pip install geopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
####### 도로명주소 위도 경도 값으로 바꿔주기 ########
from geopy.geocoders import Nominatim
geo_local = Nominatim(user_agent='South Korea')

# 위도, 경도 반환하는 함수
def geocoding(address):
    try:
        geo = geo_local.geocode(address)
        x_y = [geo.latitude, geo.longitude]
        return x_y

    except:
        return [0,0]

# %%
latitude = []
longitude =[]

for i in tqpm(org.iloc[:,28]):
    latitude.append(geocoding(i)[0])
    longitude.append(geocoding(i)[1])

# %%
org['ADDR'][342:392]
# Out:
# 343                  제주 제주시 삼양이동 2135-1번지 1층
# 344                   제주 제주시 외도일동 485-7번지 1층
# 345                       제주 제주시 노형동 748-1번지
# 346                 제주 제주시 애월읍 고내리 1113번지 1층
# 347               제주 제주시 구좌읍 세화리 1467-2번지 1층
# 348                     제주 서귀포시 동홍동 1929-7번지
# 349                 제주 제주시 외도일동 548-6번지 외도일동
# 350                  제주 제주시 오라일동 1074-6번지 1층
# 351                  제주 제주시 구좌읍 한동리 1638번지 인
# 352                  제주 제주시 한경면 저지리 1703-7번지
# 353                     제주 제주시 일도이동 1032-2번지
# 354                    제주 제주시 연동 273-53번지 1층
# 355                제주 제주시 아라일동 6114-9번지 101호
# 356            제주 제주시 애월읍 장전리 1179-1번지 1동 1층
# 357                      제주 서귀포시 동홍동 774-3번지
# 358                     제주 제주시 내도동 96-1번지 1층
# 359                 제주 서귀포시 성산읍 성산리 382-10번지
# 360                  제주 제주시 오라삼동 2997번지 201호
# 361                제주 제주시 애월읍 구엄리 600-1번지 1층
# 362              제주 서귀포시 표선면 표선리 1194-4번지 1층
# 363                  제주 제주시 한경면 신창리 271번지 1층
# ...

# %%
geocoding('제주시 조천읍 함덕리 4150')
# Out:
# [0, 0]

# %%
#api

# %%
org.loc[:,'ADR'] = ''
org.loc[:,'위도'] = ''
org.loc[:,'경도'] = ''
# Out:
# C:\Users\yunji\AppData\Local\Temp\ipykernel_5008\3983237231.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   org.loc[:,'ADR'] = ''
# C:\Users\yunji\AppData\Local\Temp\ipykernel_5008\3983237231.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   org.loc[:,'위도'] = ''
# C:\Users\yunji\AppData\Local\Temp\ipykernel_5008\3983237231.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
org.columns
# Out:
# Index(['YM', 'MCT_NM', 'OP_YMD', 'MCT_TYPE', 'ADDR', 'UE_CNT_GRP',
#        'UE_AMT_GRP', 'UE_AMT_PER_TRSN_GRP', 'MON_UE_CNT_RAT', 'TUE_UE_CNT_RAT',
#        'WED_UE_CNT_RAT', 'THU_UE_CNT_RAT', 'FRI_UE_CNT_RAT', 'SAT_UE_CNT_RAT',
#        'SUN_UE_CNT_RAT', 'HR_5_11_UE_CNT_RAT', 'HR_12_13_UE_CNT_RAT',
#        'HR_14_17_UE_CNT_RAT', 'HR_18_22_UE_CNT_RAT', 'HR_23_4_UE_CNT_RAT',
#        'LOCAL_UE_CNT_RAT', 'RC_M12_MAL_CUS_CNT_RAT', 'RC_M12_FME_CUS_CNT_RAT',
#        'RC_M12_AGE_UND_20_CUS_CNT_RAT', 'RC_M12_AGE_30_CUS_CNT_RAT',
#        'RC_M12_AGE_40_CUS_CNT_RAT', 'RC_M12_AGE_50_CUS_CNT_RAT',
#        'RC_M12_AGE_OVR_60_CUS_CNT_RAT'],
#       dtype='object')

# %%
org['ADDR'][2]
# Out:
# '제주 서귀포시 색달동 2315-1번지 한그릇'

# %%
org['ADDR'][2][3:].split('번지')
# Out:
# ['서귀포시 색달동 2315-1', ' 한그릇']

# %%
for i, e in enumerate(org.iloc[:,4]):
    org.iloc[i,28] = e[3:].split('번지')[0]

# %%
org = org.reset_index().drop('index',axis=1); org
# Out:
#           YM               MCT_NM    OP_YMD  MCT_TYPE  \
# 0     202301                 통큰돼지  20110701       가정식
# 1     202301                   해변  20050407   단품요리 전문
# 2     202301                  한그릇  20120919   단품요리 전문
# 3     202301               협재해녀의집  20130627       가정식
# 4     202301                 까망꼬숑  20220826   단품요리 전문
# ...      ...                  ...       ...       ...
# 8838  202312                  사부작  20210611       가정식
# 8839  202312         서서 아이스크림 할인점  20220825  아이스크림/빙수
# 8840  202312       버거킹 제주민속오일장DT점  20231129  샌드위치/토스트
# 8841  202312  주식회사 소라 구쟁기가김밥속에 본점  20200522        분식
# 8842  202312               새아침해장국  20231120   단품요리 전문
#
#                                          ADDR           UE_CNT_GRP  \
# 0                   제주 제주시 용담이동 2682-9번지 통큰돼지             5_75~90%
# 1                      제주 제주시 애월읍 애월리 410-6번지             3_25~50%
# 2                    제주 서귀포시 색달동 2315-1번지 한그릇             3_25~50%
# ...

# %%
# 라이브러리 설치
# !pip install googlemaps

# import 라이브러리
import googlemaps
import pandas as pd
from tqdm import tqdm

#예제 데이터 : df_shake
#컬럼 정보 : name, branch, addr

# API키 입력
mykey = "AIzaSyABLCKG6ZQk9cHsynEF6ufOjQ8WLq4kaiY"
maps = googlemaps.Client(key=mykey)  # my key값 입력

# 위도,경도 변환하는 함수 생성
def trans_geo(addr):
    try:
        geo_location = maps.geocode(addr)[0].get('geometry')
        lat = geo_location['location']['lat']
        lng =  geo_location['location']['lng']
        return [lat,lng]
    except:
        return [0,0]

# 실행
for idx, addr in enumerate(tqdm(org.iloc[:,28])):
    org.loc[idx,'위도'] = trans_geo(addr)[0]
    org.loc[idx,'경도'] = trans_geo(addr)[1]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 8843/8843 [29:04<00:00,  5.07it/s]

# %%
trans_geo('제주시 애월읍 하귀1리 156-1')
# Out:
# [33.4846105, 126.4162439]

# %%
org
# Out:
#           YM               MCT_NM    OP_YMD  MCT_TYPE  \
# 0     202301                 통큰돼지  20110701       가정식
# 1     202301                   해변  20050407   단품요리 전문
# 2     202301                  한그릇  20120919   단품요리 전문
# 3     202301               협재해녀의집  20130627       가정식
# 4     202301                 까망꼬숑  20220826   단품요리 전문
# ...      ...                  ...       ...       ...
# 8838  202312                  사부작  20210611       가정식
# 8839  202312         서서 아이스크림 할인점  20220825  아이스크림/빙수
# 8840  202312       버거킹 제주민속오일장DT점  20231129  샌드위치/토스트
# 8841  202312  주식회사 소라 구쟁기가김밥속에 본점  20200522        분식
# 8842  202312               새아침해장국  20231120   단품요리 전문
#
#                                          ADDR           UE_CNT_GRP  \
# 0                   제주 제주시 용담이동 2682-9번지 통큰돼지             5_75~90%
# 1                      제주 제주시 애월읍 애월리 410-6번지             3_25~50%
# 2                    제주 서귀포시 색달동 2315-1번지 한그릇             3_25~50%
# ...

# %%
org[['MCT_NM','ADDR','ADR','위도','경도']]
# Out:
#                    MCT_NM                                     ADDR  \
# 0                    통큰돼지                제주 제주시 용담이동 2682-9번지 통큰돼지
# 1                      해변                   제주 제주시 애월읍 애월리 410-6번지
# 2                     한그릇                 제주 서귀포시 색달동 2315-1번지 한그릇
# 3                  협재해녀의집                  제주 제주시 한림읍 협재리 1459-2번지
# 4                    까망꼬숑                  제주 제주시 노형동 3784-12번지 1층
# ...                   ...                                      ...
# 8838                  사부작                제주 서귀포시 표선면 하천리 1209번지 1층
# 8839         서서 아이스크림 할인점  제주 제주시 월평동 717번지 JDC제주첨단리슈빌아파트 상가동 102호
# 8840       버거킹 제주민속오일장DT점                    제주 제주시 연동 2413-4번지 1층
# 8841  주식회사 소라 구쟁기가김밥속에 본점                제주 서귀포시 중문동 1653-1번지 101호
# 8842               새아침해장국                  제주 제주시 도련일동 2191-9번지 1층
#
#                      ADR         위도          경도
# 0        제주시 용담이동 2682-9  33.506649  126.509172
# 1      제주시 애월읍 애월리 410-6  33.465878  126.323536
# ...

# %%
org.query('위도==0')
# Out:
#           YM MCT_NM    OP_YMD MCT_TYPE ADDR UE_CNT_GRP UE_AMT_GRP  \
# 4847  202301    돈삼춘  20170728      가정식        5_75~90%   5_75~90%
#
#      UE_AMT_PER_TRSN_GRP  MON_UE_CNT_RAT  TUE_UE_CNT_RAT  ...  \
# 4847            3_25~50%        0.173913        0.043478  ...
#
#       RC_M12_MAL_CUS_CNT_RAT  RC_M12_FME_CUS_CNT_RAT  \
# 4847                   0.665                   0.335
#
#       RC_M12_AGE_UND_20_CUS_CNT_RAT  RC_M12_AGE_30_CUS_CNT_RAT  \
# 4847                          0.206                      0.286
#
#       RC_M12_AGE_40_CUS_CNT_RAT  RC_M12_AGE_50_CUS_CNT_RAT  \
# 4847                      0.282                      0.177
#
#       RC_M12_AGE_OVR_60_CUS_CNT_RAT  ADR  위도  경도
# 4847                          0.048        0   0
#
# [1 rows x 31 columns]

# %%
org.to_csv('JEJU_MCT_위도경도.csv', index=False)

# %%
org
# Out:
#           YM               MCT_NM    OP_YMD  MCT_TYPE  \
# 0     202301                 통큰돼지  20110701       가정식
# 1     202301                   해변  20050407   단품요리 전문
# 2     202301                  한그릇  20120919   단품요리 전문
# 3     202301               협재해녀의집  20130627       가정식
# 4     202301                 까망꼬숑  20220826   단품요리 전문
# ...      ...                  ...       ...       ...
# 8838  202312                  사부작  20210611       가정식
# 8839  202312         서서 아이스크림 할인점  20220825  아이스크림/빙수
# 8840  202312       버거킹 제주민속오일장DT점  20231129  샌드위치/토스트
# 8841  202312  주식회사 소라 구쟁기가김밥속에 본점  20200522        분식
# 8842  202312               새아침해장국  20231120   단품요리 전문
#
#                                          ADDR           UE_CNT_GRP  \
# 0                   제주 제주시 용담이동 2682-9번지 통큰돼지             5_75~90%
# 1                      제주 제주시 애월읍 애월리 410-6번지             3_25~50%
# 2                    제주 서귀포시 색달동 2315-1번지 한그릇             3_25~50%
# ...

# %%
org_
# Out:
#            YM        MCT_NM    OP_YMD MCT_TYPE                        ADDR  \
# 0      202301          통큰돼지  20110701      가정식   제주 제주시 용담이동 2682-9번지 통큰돼지
# 1      202301            해변  20050407  단품요리 전문      제주 제주시 애월읍 애월리 410-6번지
# 2      202301           한그릇  20120919  단품요리 전문    제주 서귀포시 색달동 2315-1번지 한그릇
# 3      202301        협재해녀의집  20130627      가정식     제주 제주시 한림읍 협재리 1459-2번지
# 4      202301          까망꼬숑  20220826  단품요리 전문     제주 제주시 노형동 3784-12번지 1층
# ...       ...           ...       ...      ...                         ...
# 67859  202312           미나리  20230630      가정식       제주 제주시 연동 291-24번지 연동
# 67860  202312      종달리엔심야식당  20210513      가정식  제주 제주시 구좌읍 종달리 1935-1번지 1층
# 67861  202312          경일낙지  20020112  단품요리 전문         제주 제주시 노형동 1291-3번지
# 67862  202312      흑돼지가있는풍경  20040109      가정식            제주 제주시 노형동 668번지
# 67863  202312  에이바우트커피삼무공원점  20200602       커피       제주 제주시 연동 260-21번지 1층
#
# ...

# %%
Seoul = (33.506649, 126.509172)  #Latitude, Longitude
Toronto = (33.465878, 126.323536)

# 거리 계산
haversine(Seoul, Toronto, unit = 'km')
# Out:
# 17.802561943461694

# %%
sumdf = pd.merge(org_, org[['ADDR', '위도', '경도']], on='ADDR', how='left');sumdf
# Out:
#            YM        MCT_NM    OP_YMD MCT_TYPE                        ADDR  \
# 0      202301          통큰돼지  20110701      가정식   제주 제주시 용담이동 2682-9번지 통큰돼지
# 1      202301            해변  20050407  단품요리 전문      제주 제주시 애월읍 애월리 410-6번지
# 2      202301           한그릇  20120919  단품요리 전문    제주 서귀포시 색달동 2315-1번지 한그릇
# 3      202301        협재해녀의집  20130627      가정식     제주 제주시 한림읍 협재리 1459-2번지
# 4      202301          까망꼬숑  20220826  단품요리 전문     제주 제주시 노형동 3784-12번지 1층
# ...       ...           ...       ...      ...                         ...
# 67859  202312           미나리  20230630      가정식       제주 제주시 연동 291-24번지 연동
# 67860  202312      종달리엔심야식당  20210513      가정식  제주 제주시 구좌읍 종달리 1935-1번지 1층
# 67861  202312          경일낙지  20020112  단품요리 전문         제주 제주시 노형동 1291-3번지
# 67862  202312      흑돼지가있는풍경  20040109      가정식            제주 제주시 노형동 668번지
# 67863  202312  에이바우트커피삼무공원점  20200602       커피       제주 제주시 연동 260-21번지 1층
#
# ...

# %%
sumdf.to_csv('JEJU_MCT_위도경도SUM.csv', index=False)

# %%
import requests
import math

kakao_key = open("kakao.txt", "r").read()

def __get_distance_result__(x1, y1, x2, y2):
    return math.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2) 


def get_distance_between_to_address(addr1, addr2):
    response = requests.get(
        "https://dapi.kakao.com/v2/local/search/address.json",
        params={"query": addr1},
        headers={"Authorization": "KakaoAK " + kakao_key},
    ).json()
    x, y = response["documents"][0]["x"], response["documents"][0]["y"]  # x, y= 위도, 경도

    response = requests.get(
        "https://dapi.kakao.com/v2/local/geo/transcoord.json",
        params={"x": x, "y": y, "output_coord": "WTM"},
        headers={"Authorization": "KakaoAK " + kakao_key},
    ).json()
    # x1, y1 = 위경도를 WTM으로 변환
    x1, y1 = response["documents"][0]["x"], response["documents"][0]["y"]

    response = requests.get(
        "https://dapi.kakao.com/v2/local/search/address.json",
        params={"query": addr2},
        headers={"Authorization": "KakaoAK " + kakao_key},
    ).json()
    x, y = response["documents"][0]["x"], response["documents"][0]["y"]

    response = requests.get(
        "https://dapi.kakao.com/v2/local/geo/transcoord.json",
        params={"x": x, "y": y, "output_coord": "WTM"},
        headers={"Authorization": "KakaoAK " + kakao_key},
    ).json()
    x2, y2 = response["documents"][0]["x"], response["documents"][0]["y"]

    return __get_distance_result__(x1, y1, x2, y2)


print(get_distance_between_to_address("제주 제주시 일도일동 1146번지", "서울 강동구 올림픽로 610 천호효성해링턴타워"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[105], line 43
#      38     x2, y2 = response["documents"][0]["x"], response["documents"][0]["y"]
#      40     return __get_distance_result__(x1, y1, x2, y2)
# ---> 43 print(get_distance_between_to_address("제주 제주시 일도일동 1146번지", "서울 강동구 올림픽로 610 천호효성해링턴타워"))
#
# Cell In[105], line 16, in get_distance_between_to_address(addr1, addr2)
#      10 def get_distance_between_to_address(addr1, addr2):
#      11     response = requests.get(
#      12         "https://dapi.kakao.com/v2/local/search/address.json",
#      13         params={"query": addr1},
#      14         headers={"Authorization": "KakaoAK " + kakao_key},
#      15     ).json()
# ---> 16     x, y = response["documents"][0]["x"], response["documents"][0]["y"]  # x, y= 위도, 경도
#      18     response = requests.get(
# ...

# %%
org = pd.read_csv('생성형AI분야_로우데이터/JEJU_MCT_DATA_v2.csv', encoding = "cp949")

# %%
ad = pd.read_csv('생성형AI분야_로우데이터/JEJU_MCT_DATA_v2.csv', encoding = "cp949")["ADDR"]

# %%
org['x1'] = ""
org['y1'] = ""

# %%
org["MCT_NM"].nunique()
# Out:
# 9252

# %%
org["MCT_NM"].value_counts()
# Out:
# MCT_NM
# 쭈꾸쭈꾸쭈꾸미    24
# 뽈살집        24
# 마리조아       24
# 황금어장       24
# 이치진        24
#            ..
# 정성푸드        1
# 대양회초밥       1
# 제주창스닥       1
# 월스낵         1
# 새아침해장국      1
# Name: count, Length: 9252, dtype: int64

# %%
org.query(org['MCT_NM']=="쭈꾸쭈꾸쭈꾸미")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 org.query(org['MCT_NM']=="쭈꾸쭈꾸쭈꾸미")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4820, in DataFrame.query(self, expr, inplace, **kwargs)
#    4818 if not isinstance(expr, str):
#    4819     msg = f"expr must be a string to be evaluated, {type(expr)} given"
# -> 4820     raise ValueError(msg)
#    4821 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822 kwargs["target"] = None
#
# ValueError: expr must be a string to be evaluated, <class 'pandas.core.series.Series'> given

# %%
org.drop_duplicates(['ADDR'])[:3]
# Out:
#        YM MCT_NM    OP_YMD MCT_TYPE                       ADDR UE_CNT_GRP  \
# 0  202301   통큰돼지  20110701      가정식  제주 제주시 용담이동 2682-9번지 통큰돼지   5_75~90%
# 1  202301     해변  20050407  단품요리 전문     제주 제주시 애월읍 애월리 410-6번지   3_25~50%
# 2  202301    한그릇  20120919  단품요리 전문   제주 서귀포시 색달동 2315-1번지 한그릇   3_25~50%
#
#   UE_AMT_GRP UE_AMT_PER_TRSN_GRP  MON_UE_CNT_RAT  TUE_UE_CNT_RAT  ...  \
# 0   4_50~75%            3_25~50%        0.161290        0.032258  ...
# 1   2_10~25%            2_10~25%        0.090909        0.121212  ...
# 2   3_25~50%            4_50~75%        0.224719        0.112360  ...
#
#    LOCAL_UE_CNT_RAT  RC_M12_MAL_CUS_CNT_RAT  RC_M12_FME_CUS_CNT_RAT  \
# 0          0.707763                   0.610                   0.390
# 1          0.230928                   0.542                   0.458
# 2          0.347059                   0.529                   0.471
#
#    RC_M12_AGE_UND_20_CUS_CNT_RAT  RC_M12_AGE_30_CUS_CNT_RAT  \
# ...

# %%
math.sqrt((145537.01 - 137116.02)** 2 + (-26064.640008-2875.340008) ** 2) #실제 31 km 비슷
# Out:
# 30140.264031799383

# %%
kakao_key = open("kakao.txt", "r").read()
def get_distance_between_to_address(addr1, i):
    response = requests.get(
        "https://dapi.kakao.com/v2/local/search/address.json",
        params={"query": addr1},
        headers={"Authorization": "KakaoAK " + kakao_key},
    ).json()
    x, y = response["documents"][0]["x"], response["documents"][0]["y"]  # x, y= 위도, 경도

    # response = requests.get(
    #     "https://dapi.kakao.com/v2/local/geo/transcoord.json",
    #     params={"x": x, "y": y, "output_coord": "WTM"},
    #     headers={"Authorization": "KakaoAK " + kakao_key},
    # ).json()
    # # x1, y1 = 위경도를 WTM으로 변환
    # x1, y1 = response["documents"][0]["x"], response["documents"][0]["y"]

    org.iloc[i,28] = x
    org.iloc[i,29] = y

# %%
pip install haversine
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from haversine import haversine

# %%
# 위경도 입력
Seoul = (33.5066481356656, 126.509165318787)  #Latitude, Longitude
Toronto = (33.465878379509, 126.323536037201)

# 거리 계산
haversine(Seoul, Toronto, unit = 'km')
# Out:
# 17.801924253182825

# %%
get_distance_between_to_address(ad[1], 1)

# %%
lst = []
for i in tqdm(range(5000)):
    try:
        get_distance_between_to_address(ad[i], i)
    except Exception as e:
        lst.append(ad[i])
        pass
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 5000/5000 [03:23<00:00, 24.55it/s]

# %%
org.[:5]
# Out:
#        YM  MCT_NM    OP_YMD MCT_TYPE                       ADDR UE_CNT_GRP  \
# 0  202301    통큰돼지  20110701      가정식  제주 제주시 용담이동 2682-9번지 통큰돼지   5_75~90%
# 1  202301      해변  20050407  단품요리 전문     제주 제주시 애월읍 애월리 410-6번지   3_25~50%
# 2  202301     한그릇  20120919  단품요리 전문   제주 서귀포시 색달동 2315-1번지 한그릇   3_25~50%
# 3  202301  협재해녀의집  20130627      가정식    제주 제주시 한림읍 협재리 1459-2번지   3_25~50%
# 4  202301    까망꼬숑  20220826  단품요리 전문    제주 제주시 노형동 3784-12번지 1층   5_75~90%
#
#   UE_AMT_GRP UE_AMT_PER_TRSN_GRP  MON_UE_CNT_RAT  TUE_UE_CNT_RAT  ...  \
# 0   4_50~75%            3_25~50%        0.161290        0.032258  ...
# 1   2_10~25%            2_10~25%        0.090909        0.121212  ...
# 2   3_25~50%            4_50~75%        0.224719        0.112360  ...
# 3   3_25~50%            4_50~75%        0.000000        0.271739  ...
# 4   3_25~50%            2_10~25%        0.272727        0.121212  ...
#
#    LOCAL_UE_CNT_RAT  RC_M12_MAL_CUS_CNT_RAT  RC_M12_FME_CUS_CNT_RAT  \
# ...

# %%
response = requests.get(
        "https://dapi.kakao.com/v2/local/search/address.json",
        params={"query": "제주 제주시 한림읍 협재리 1459-2"},
        headers={"Authorization": "KakaoAK " + kakao_key},
    ).json()
response
# Out:
# {'errorType': 'RequestThrottled', 'message': 'API limit has been exceeded.'}

# %%
response = requests.get(
        "https://dapi.kakao.com/v2/local/search/address.json",
        params={"query": "제주 제주시 일도일동 1146번지"},
        headers={"Authorization": "KakaoAK " + kakao_key},
    ).json()

# %%
response
# Out:
# {'errorType': 'RequestThrottled', 'message': 'API limit has been exceeded.'}
